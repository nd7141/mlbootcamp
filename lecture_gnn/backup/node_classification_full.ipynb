# %% [markdown]
# # Node Classification with DGL
#
# This notebooks adopts [the tutorial in DGL](https://docs.dgl.ai/en/0.4.x/tutorials/models/1_gnn/9_gat.html).

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))



import os
import sys
import time
# Out:
# <style>.container { width:100% !important; }</style>

# %%
if 'google.colab' in sys.modules:
    # !pip install dgl-cu101

# %%
# Import libs
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

os.environ['DGLBACKEND'] = 'pytorch'  # tell DGL what backend to use
import dgl
from dgl import DGLGraph
from dgl.data import MiniGCDataset

import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

from dgl import DGLGraph
from dgl.data import citation_graph as citegrh
import networkx as nx

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ## Download node classification graph

# %% [markdown]
# [Cora dataset](https://docs.dgl.ai/en/0.4.x/api/python/data.html#dgl.data.CoraDataset) is a popular citation network, where nodes are papers and edges are citation relationships.
# Node features are bag of words of topics appearing in each paper. Each node has a target label, which is the category of a paper.
#
# It's used often as a benchmark dataset in semi-supervised node classification, i.e. we are given access to the whole graph and node features, but train our model only small subset of nodes  (140 out 2708 nodes). We then apply our trained model on the same graph but different subset of nodes' target labels.

# %%
def load_cora_data():
    data = citegrh.load_cora()
    features = torch.FloatTensor(data.features)
    labels = torch.LongTensor(data.labels)
    train_mask = torch.BoolTensor(data.train_mask)
    val_mask = torch.BoolTensor(data.val_mask)
    test_mask = torch.BoolTensor(data.test_mask)
    g = DGLGraph(data.graph)
    
    return g, features, labels, train_mask, val_mask, test_mask

# get graph, features, labels, and masks
g, features, labels, train_mask, val_mask, test_mask = load_cora_data()
# Out:
# Loading from cache failed, re-processing.
# Finished data loading and preprocessing.
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done saving data into cached files.

# %% [markdown]
# ## Define GAT model

# %% [markdown]
# GAT introduces the attention mechanism as a substitute for the statically normalized convolution operation. Below are the equations to compute the node embedding $h^{(l+1)}_i$ of layer $l+1$ from the embeddings of layer $l$.

# %% [markdown]
# <img src="https://data.dgl.ai/tutorial/gat/gat.png" width="500" height="600">
# <!-- ![a](https://data.dgl.ai/tutorial/gat/gat.png) -->

# %% [markdown]
# \begin{split}\begin{align}
# z_i^{(l)}&=W^{(l)}h_i^{(l)},&(1) \\
# e_{ij}^{(l)}&=\text{LeakyReLU}(\vec a^{(l)^T}(z_i^{(l)}||z_j^{(l)})),&(2)\\
# \alpha_{ij}^{(l)}&=\frac{\exp(e_{ij}^{(l)})}{\sum_{k\in \mathcal{N}(i)}^{}\exp(e_{ik}^{(l)})},&(3)\\
# h_i^{(l+1)}&=\sigma\left(\sum_{j\in \mathcal{N}(i)} {\alpha^{(l)}_{ij} z^{(l)}_j }\right),&(4)
# \end{align}\end{split}

# %% [markdown]
# <p>Explanations:</p>
# <ul class="simple">
# <li>Equation (1) is a linear transformation of the lower layer embedding <span class="math notranslate nohighlight">\(h_i^{(l)}\)</span>
# and <span class="math notranslate nohighlight">\(W^{(l)}\)</span> is its learnable weight matrix.</li>
# <li>Equation (2) computes a pair-wise <em>un-normalized</em> attention score between two neighbors.
# Here, it first concatenates the <span class="math notranslate nohighlight">\(z\)</span> embeddings of the two nodes, where <span class="math notranslate nohighlight">\(||\)</span>
# denotes concatenation, then takes a dot product of it and a learnable weight vector
# <span class="math notranslate nohighlight">\(\vec a^{(l)}\)</span>, and applies a LeakyReLU in the end. This form of attention is
# usually called <em>additive attention</em>, contrast with the dot-product attention in the
# Transformer model.</li>
# <li>Equation (3) applies a softmax to normalize the attention scores on each node’s
# incoming edges.</li>
# <li>Equation (4) is similar to GCN. The embeddings from neighbors are aggregated together,
# scaled by the attention scores.</li>
# </ul>
# </div>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class GATLayer(nn.Module):
    def __init__(self, g, in_dim, out_dim):
        super(GATLayer, self).__init__()
        self.g = g
        # equation (1)
        self.fc = nn.Linear(in_dim, out_dim, bias=False)
        # equation (2)
        self.attn_fc = nn.Linear(2 * out_dim, 1, bias=False)
        self.reset_parameters()

    def reset_parameters(self):
        """Reinitialize learnable parameters."""
        gain = nn.init.calculate_gain('relu')
        nn.init.xavier_normal_(self.fc.weight, gain=gain)
        nn.init.xavier_normal_(self.attn_fc.weight, gain=gain)

    def edge_attention(self, edges):
        # edge UDF for equation (2)
        z2 = torch.cat([edges.src['z'], edges.dst['z']], dim=1)
        a = self.attn_fc(z2)
        return {'e': F.leaky_relu(a)}

    def message_func(self, edges):
        # message UDF for equation (3) & (4)
        return {'z': edges.src['z'], 'e': edges.data['e']}

    def reduce_func(self, nodes):
        # reduce UDF for equation (3) & (4)
        # equation (3)
        alpha = F.softmax(nodes.mailbox['e'], dim=1)
        # equation (4)
        h = torch.sum(alpha * nodes.mailbox['z'], dim=1)
        return {'h': h}

    def forward(self, h):
        # equation (1)
        z = self.fc(h)
        self.g.ndata['z'] = z
        # equation (2)
        self.g.apply_edges(self.edge_attention)
        # equation (3) & (4)
        self.g.update_all(self.message_func, self.reduce_func)
        return self.g.ndata.pop('h')

# %%
class MultiHeadGATLayer(nn.Module):
    def __init__(self, g, in_dim, out_dim, num_heads, merge='cat'):
        super(MultiHeadGATLayer, self).__init__()
        self.heads = nn.ModuleList()
        for i in range(num_heads):
            self.heads.append(GATLayer(g, in_dim, out_dim))
        self.merge = merge

    def forward(self, h):
        head_outs = [attn_head(h) for attn_head in self.heads]
        if self.merge == 'cat':
            # concat on the output feature dimension (dim=1)
            return torch.cat(head_outs, dim=1)
        else:
            # merge using average
            return torch.mean(torch.stack(head_outs))

# %%
class GAT(nn.Module):
    def __init__(self, g, in_dim, hidden_dim, out_dim, num_heads):
        super(GAT, self).__init__()
        self.layer1 = MultiHeadGATLayer(g, in_dim, hidden_dim, num_heads)
        # Be aware that the input dimension is hidden_dim*num_heads since
        # multiple head outputs are concatenated together. Also, only
        # one attention head in the output layer.
        self.layer2 = MultiHeadGATLayer(g, hidden_dim * num_heads, out_dim, 1)

    def forward(self, h):
        h = self.layer1(h)
        h = F.elu(h)
        h = self.layer2(h)
        return h

# %% [markdown]
# ## Define training pipeline

# %% [markdown]
# Now that we have a GNN model, we need to train and evaluate it.
#
# ### Exercise 1.1:
# <p>Instructions:</p>
# <ol class="simple">
# <li>Define a GAT model with 8 heads of hidden dimension 8.</li>
#
# <li>Define Adam optimizer with GNN parameters.</li>
# <li>Compute a loss (cross entropy in classification) and accuracy of the model on training nodes.</li>
# <li>Evaluate the model on test nodes.</li>
# </ol>

# %%
import time
import numpy as np

# if you have gpu, move tensors and models there
g = g.to('cuda')
features = features.cuda()
labels = labels.cuda()

# define a GAT model with hidden_dim=8 and heads=8
net = GAT(g,
          in_dim=features.size()[1],
          hidden_dim=8,
          out_dim=7,
          num_heads=8).cuda()

# create optimizer
optimizer = torch.optim.Adam(net.parameters(), lr=1e-2)

def evaluate(net, labels, features, mask):
    net.eval()
    y = labels[mask]
    logits = net(features)
    with torch.no_grad():
        pred = logits[mask]
        loss = F.cross_entropy(pred, y.long())
        acc = torch.Tensor([(y == pred.max(1)[1]).sum().item()/y.shape[0]])

        return loss, acc

# main loop
xs = list(range(30))
ys = []
for epoch in xs:
    start2epoch = time.time()

    net.train()
    logits = net(features)
    train_loss = F.cross_entropy(logits[train_mask], labels[train_mask])
    train_acc = torch.Tensor([(labels[train_mask] == logits[train_mask].max(1)[1]).sum().item()/labels[train_mask].shape[0]])
    

    optimizer.zero_grad()
    train_loss.backward()
    optimizer.step()
    
    test_loss, test_acc = evaluate(net, labels, features, test_mask)
    
    ys.append([train_loss, test_loss, train_acc, test_acc])
    

    print("Epoch {:05d} | Train Loss {:.3f} | Test Loss {:.3f} | Train Acc {:.2f} | Test Acc {:.2f} | Time(s) {:.2f}".format(
        epoch, train_loss.item(), test_loss.item(), train_acc.item(), test_acc.item(), time.time() - start2epoch))
# Out:
# Epoch 00000 | Train Loss 1.945 | Test Loss 1.921 | Train Acc 0.18 | Test Acc 0.63 | Time(s) 0.52
# Epoch 00001 | Train Loss 1.900 | Test Loss 1.897 | Train Acc 0.90 | Test Acc 0.70 | Time(s) 0.51
# Epoch 00002 | Train Loss 1.855 | Test Loss 1.871 | Train Acc 0.95 | Test Acc 0.71 | Time(s) 0.59
# Epoch 00003 | Train Loss 1.807 | Test Loss 1.844 | Train Acc 0.96 | Test Acc 0.71 | Time(s) 0.52
# Epoch 00004 | Train Loss 1.756 | Test Loss 1.816 | Train Acc 0.96 | Test Acc 0.72 | Time(s) 0.52
# Epoch 00005 | Train Loss 1.704 | Test Loss 1.786 | Train Acc 0.96 | Test Acc 0.72 | Time(s) 0.51
# Epoch 00006 | Train Loss 1.648 | Test Loss 1.754 | Train Acc 0.96 | Test Acc 0.73 | Time(s) 0.52
# Epoch 00007 | Train Loss 1.590 | Test Loss 1.721 | Train Acc 0.96 | Test Acc 0.73 | Time(s) 0.52
# Epoch 00008 | Train Loss 1.530 | Test Loss 1.686 | Train Acc 0.97 | Test Acc 0.73 | Time(s) 0.51
# Epoch 00009 | Train Loss 1.467 | Test Loss 1.650 | Train Acc 0.98 | Test Acc 0.73 | Time(s) 0.51
# Epoch 00010 | Train Loss 1.403 | Test Loss 1.613 | Train Acc 0.98 | Test Acc 0.73 | Time(s) 0.52
# Epoch 00011 | Train Loss 1.336 | Test Loss 1.575 | Train Acc 0.98 | Test Acc 0.74 | Time(s) 0.53
# Epoch 00012 | Train Loss 1.269 | Test Loss 1.536 | Train Acc 0.98 | Test Acc 0.74 | Time(s) 0.52
# Epoch 00013 | Train Loss 1.200 | Test Loss 1.495 | Train Acc 0.98 | Test Acc 0.74 | Time(s) 0.51
# Epoch 00014 | Train Loss 1.131 | Test Loss 1.455 | Train Acc 0.98 | Test Acc 0.74 | Time(s) 0.51
# Epoch 00015 | Train Loss 1.061 | Test Loss 1.414 | Train Acc 0.98 | Test Acc 0.74 | Time(s) 0.52
# Epoch 00016 | Train Loss 0.992 | Test Loss 1.372 | Train Acc 0.98 | Test Acc 0.74 | Time(s) 0.52
# Epoch 00017 | Train Loss 0.923 | Test Loss 1.332 | Train Acc 0.98 | Test Acc 0.74 | Time(s) 0.51
# Epoch 00018 | Train Loss 0.855 | Test Loss 1.291 | Train Acc 0.98 | Test Acc 0.73 | Time(s) 0.52
# Epoch 00019 | Train Loss 0.790 | Test Loss 1.252 | Train Acc 0.98 | Test Acc 0.74 | Time(s) 0.53
# Epoch 00020 | Train Loss 0.726 | Test Loss 1.214 | Train Acc 0.98 | Test Acc 0.73 | Time(s) 0.52
# Epoch 00021 | Train Loss 0.665 | Test Loss 1.177 | Train Acc 0.98 | Test Acc 0.73 | Time(s) 0.51
# Epoch 00022 | Train Loss 0.607 | Test Loss 1.142 | Train Acc 0.97 | Test Acc 0.73 | Time(s) 0.53
# Epoch 00023 | Train Loss 0.553 | Test Loss 1.109 | Train Acc 0.97 | Test Acc 0.73 | Time(s) 0.52
# Epoch 00024 | Train Loss 0.501 | Test Loss 1.079 | Train Acc 0.97 | Test Acc 0.72 | Time(s) 0.51
# Epoch 00025 | Train Loss 0.453 | Test Loss 1.051 | Train Acc 0.97 | Test Acc 0.73 | Time(s) 0.52
# Epoch 00026 | Train Loss 0.409 | Test Loss 1.025 | Train Acc 0.97 | Test Acc 0.73 | Time(s) 0.53
# Epoch 00027 | Train Loss 0.369 | Test Loss 1.003 | Train Acc 0.98 | Test Acc 0.72 | Time(s) 0.52
# Epoch 00028 | Train Loss 0.332 | Test Loss 0.983 | Train Acc 0.98 | Test Acc 0.72 | Time(s) 0.51
# Epoch 00029 | Train Loss 0.299 | Test Loss 0.965 | Train Acc 0.98 | Test Acc 0.72 | Time(s) 0.52

# %%
def set_default(figsize=(10, 10), dpi=100):
    plt.style.use(['dark_background', 'bmh'])
    plt.rc('axes', facecolor='k')
    plt.rc('figure', facecolor='k')
    plt.rc('figure', figsize=figsize, dpi=dpi)

set_default(figsize=(3, 3), dpi=150)

def plot(xs, ys, legend, title, output_fn=None, logx=False, logy=False, ylabel='Accuracy'):
        y = list(zip(*ys))

        plt.rcParams.update({'font.size': 40})
        plt.rcParams["figure.figsize"] = (20, 10)
        lss = ['-', '--', '-.', ':']
        colors = ['#4053d3', '#ddb310', '#b51d14', '#00beff', '#fb49b0', '#00b25d', '#cacaca']
        colors = [(235, 172, 35), (184, 0, 88), (0, 140, 249), (0, 110, 0), (0, 187, 173), (209, 99, 230), (178, 69, 2),
                  (255, 146, 135), (89, 84, 214), (0, 198, 248), (135, 133, 0), (0, 167, 108), (189, 189, 189)]
        colors = [[p / 255 for p in c] for c in colors]
        for i in range(len(y)):
            plt.plot(xs, y[i], lw=4, color=colors[i])
        plt.legend(legend, loc=1, fontsize=30)
        plt.title(title)

        plt.xscale('log') if logx else None
        plt.yscale('log') if logy else None
        plt.xlabel('Iteration')
        plt.ylabel('Accuracy')
        plt.grid()
        plt.tight_layout()

        plt.savefig(output_fn, bbox_inches='tight') if output_fn else None
        plt.show()

# %%
plot(xs, ys, legend=['Train Loss', 'Test Loss', 'Train Accuracy', 'Test Accuracy'], title='Metrics')

# %% [markdown]
# ### Define optimized GNN models

# %% [markdown]
# Many GNN models are already implemented in DGL and are optimized. You can find the list of all [available GNN layers here](https://docs.dgl.ai/en/0.4.x/api/python/nn.pytorch.html).
#
# ### Exercise 2.1
#
# <p>Instructions:</p>
# <ol>
# <li>Import GatConv layer.</li>
#
# <li>Create two layer GAT network with dropout and residual connection.</li>
# <li>Run this model through the same pipeline.</li>
# </ol>
#
#
# <p>Questions:</p>
# <ol>
# <li>How much faster this GAT network runs compared to previously defined model?</li>
# <li>What is the performance of the model?</li>
# </ol>
#
#
# ### Exercise 2.2
# <p>Instructions:</p>
# <ol>
# <li>Try other GNN layers. For example, GraphConv, ChebConv, AGGNConv.</li>
#
# <li>Create 2-layer GNN network with these layers.</li>
# <li>Run this model through the same pipeline.</li>
# </ol>
#
#
# <p>Questions:</p>
# <ol>
# <li>What is the performance compared to GAT model in terms of running time and speed.</li>
# </ol>

# %%
from dgl.nn.pytorch import GATConv as GATConvDGL, GraphConv, ChebConv as ChebConvDGL, \
    AGNNConv as AGNNConvDGL, APPNPConv

import torch
from torch.nn import Dropout, ELU, Sequential, Linear, ReLU, Identity
import torch.nn.functional as F

class GNNModelDGL(torch.nn.Module):
    def __init__(self, graph, in_dim, hidden_dim, out_dim,
                 heads=8, dropout=0., name='gat', residual=True, use_mlp=False, join_with_mlp=False):
        super(GNNModelDGL, self).__init__()
        self.name = name
        self.graph = graph
        self.use_mlp = use_mlp
        self.join_with_mlp = join_with_mlp
        if use_mlp:
            self.mlp = MLPRegressor(in_dim, hidden_dim, out_dim)
            if join_with_mlp:
                in_dim += 1
            else:
                in_dim = out_dim
        if name == 'gat':
            self.l1 = GATConvDGL(in_dim, hidden_dim, heads, feat_drop=dropout, attn_drop=dropout, residual=False,
                              activation=F.elu)
            self.l2 = GATConvDGL(hidden_dim * heads, out_dim, 1, feat_drop=dropout, attn_drop=dropout, residual=residual, activation=None)
        elif name == 'gcn':
            self.l1 = GraphConv(in_dim, hidden_dim, activation=F.elu)
            self.l2 = GraphConv(hidden_dim, out_dim, activation=F.elu)
            self.drop = Dropout(p=dropout)
        elif name == 'cheb':
            self.l1 = ChebConvDGL(in_dim, hidden_dim, k = 3)
            self.l2 = ChebConvDGL(hidden_dim, out_dim, k = 3)
            self.drop = Dropout(p=dropout)
        elif name == 'agnn':
            self.lin1 = Sequential(Dropout(p=dropout), Linear(in_dim, hidden_dim), ELU())
            self.l1 = AGNNConvDGL(learn_beta=False)
            self.l2 = AGNNConvDGL(learn_beta=True)
            self.lin2 = Sequential(Dropout(p=dropout), Linear(hidden_dim, out_dim), ELU())
        elif name == 'appnp':
            self.mlp = Sequential(Dropout(p=dropout), Linear(in_dim, hidden_dim),
                       ELU(), Dropout(p=dropout), Linear(hidden_dim, out_dim), ELU())
            self.l1 = APPNPConv(k=10, alpha=0.1)


    def forward(self, features):
        h = features
        graph = self.graph
        if self.use_mlp:
            if self.join_with_mlp:
                h = torch.cat((h, self.mlp(features)), 1)
            else:
                h = self.mlp(features)
        if self.name == 'gat':
            h = self.l1(graph, h).flatten(1)
            logits = self.l2(graph, h).mean(1)
        elif self.name in ['appnp']:
            h = self.mlp(h)
            logits = self.l1(graph, h)
        elif self.name == 'agnn':
            h = self.lin1(h)
            h = self.l1(graph, h)
            h = self.l2(graph, h)
            logits = self.lin2(h)
        elif self.name in ['gcn', 'cheb']:
            h = self.drop(h)
            h = self.l1(graph, h)
            logits = self.l2(graph, h)


        return logits

# %%
# if you have gpu, move tensors and models there
g = g.to('cuda')
features = features.cuda()
labels = labels.cuda()

# define a GAT model with hidden_dim=8 and heads=8
net = GNNModelDGL(g,
          in_dim=features.size()[1],
          hidden_dim=8,
          out_dim=7,
          name='appnp').cuda()

# create optimizer
optimizer = torch.optim.Adam(net.parameters(), lr=1e-2)

def evaluate(net, labels, features, mask):
    net.eval()
    y = labels[mask]
    logits = net(features)
    with torch.no_grad():
        pred = logits[mask]
        loss = F.cross_entropy(pred, y.long())
        acc = torch.Tensor([(y == pred.max(1)[1]).sum().item()/y.shape[0]])

        return loss, acc

# main loop
xs = list(range(100))
ys = []
for epoch in xs:
    start2epoch = time.time()

    net.train()
    logits = net(features)
    train_loss = F.cross_entropy(logits[train_mask], labels[train_mask])
    train_acc = torch.Tensor([(labels[train_mask] == logits[train_mask].max(1)[1]).sum().item()/labels[train_mask].shape[0]])
    

    optimizer.zero_grad()
    train_loss.backward()
    optimizer.step()
    
    test_loss, test_acc = evaluate(net, labels, features, test_mask)
    
    ys.append([train_loss, test_loss, train_acc, test_acc])
    

    print("Epoch {:05d} | Train Loss {:.3f} | Test Loss {:.3f} | Train Acc {:.2f} | Test Acc {:.2f} | Time(s) {:.2f}".format(
        epoch, train_loss.item(), test_loss.item(), train_acc.item(), test_acc.item(), time.time() - start2epoch))
# Out:
# Epoch 00000 | Train Loss 1.957 | Test Loss 1.948 | Train Acc 0.14 | Test Acc 0.15 | Time(s) 0.02
# Epoch 00001 | Train Loss 1.950 | Test Loss 1.947 | Train Acc 0.14 | Test Acc 0.15 | Time(s) 0.02
# Epoch 00002 | Train Loss 1.944 | Test Loss 1.945 | Train Acc 0.14 | Test Acc 0.15 | Time(s) 0.02
# Epoch 00003 | Train Loss 1.939 | Test Loss 1.944 | Train Acc 0.14 | Test Acc 0.15 | Time(s) 0.02
# Epoch 00004 | Train Loss 1.933 | Test Loss 1.941 | Train Acc 0.14 | Test Acc 0.15 | Time(s) 0.02
# Epoch 00005 | Train Loss 1.927 | Test Loss 1.938 | Train Acc 0.14 | Test Acc 0.25 | Time(s) 0.02
# Epoch 00006 | Train Loss 1.921 | Test Loss 1.934 | Train Acc 0.31 | Test Acc 0.25 | Time(s) 0.02
# Epoch 00007 | Train Loss 1.914 | Test Loss 1.930 | Train Acc 0.31 | Test Acc 0.23 | Time(s) 0.02
# Epoch 00008 | Train Loss 1.907 | Test Loss 1.924 | Train Acc 0.29 | Test Acc 0.20 | Time(s) 0.02
# Epoch 00009 | Train Loss 1.900 | Test Loss 1.918 | Train Acc 0.26 | Test Acc 0.20 | Time(s) 0.02
# Epoch 00010 | Train Loss 1.893 | Test Loss 1.911 | Train Acc 0.31 | Test Acc 0.23 | Time(s) 0.02
# Epoch 00011 | Train Loss 1.886 | Test Loss 1.903 | Train Acc 0.36 | Test Acc 0.36 | Time(s) 0.02
# Epoch 00012 | Train Loss 1.878 | Test Loss 1.895 | Train Acc 0.44 | Test Acc 0.46 | Time(s) 0.02
# Epoch 00013 | Train Loss 1.870 | Test Loss 1.887 | Train Acc 0.52 | Test Acc 0.49 | Time(s) 0.02
# Epoch 00014 | Train Loss 1.861 | Test Loss 1.879 | Train Acc 0.53 | Test Acc 0.52 | Time(s) 0.02
# Epoch 00015 | Train Loss 1.852 | Test Loss 1.871 | Train Acc 0.55 | Test Acc 0.54 | Time(s) 0.02
# Epoch 00016 | Train Loss 1.843 | Test Loss 1.863 | Train Acc 0.56 | Test Acc 0.55 | Time(s) 0.02
# Epoch 00017 | Train Loss 1.833 | Test Loss 1.855 | Train Acc 0.56 | Test Acc 0.56 | Time(s) 0.02
# Epoch 00018 | Train Loss 1.822 | Test Loss 1.847 | Train Acc 0.57 | Test Acc 0.57 | Time(s) 0.02
# Epoch 00019 | Train Loss 1.811 | Test Loss 1.840 | Train Acc 0.62 | Test Acc 0.58 | Time(s) 0.02
# Epoch 00020 | Train Loss 1.800 | Test Loss 1.833 | Train Acc 0.63 | Test Acc 0.62 | Time(s) 0.02
# Epoch 00021 | Train Loss 1.788 | Test Loss 1.825 | Train Acc 0.68 | Test Acc 0.64 | Time(s) 0.02
# Epoch 00022 | Train Loss 1.775 | Test Loss 1.819 | Train Acc 0.74 | Test Acc 0.66 | Time(s) 0.02
# Epoch 00023 | Train Loss 1.762 | Test Loss 1.812 | Train Acc 0.80 | Test Acc 0.67 | Time(s) 0.02
# Epoch 00024 | Train Loss 1.749 | Test Loss 1.805 | Train Acc 0.85 | Test Acc 0.68 | Time(s) 0.02
# Epoch 00025 | Train Loss 1.735 | Test Loss 1.798 | Train Acc 0.87 | Test Acc 0.67 | Time(s) 0.02
# Epoch 00026 | Train Loss 1.721 | Test Loss 1.791 | Train Acc 0.89 | Test Acc 0.66 | Time(s) 0.02
# Epoch 00027 | Train Loss 1.707 | Test Loss 1.783 | Train Acc 0.87 | Test Acc 0.65 | Time(s) 0.02
# Epoch 00028 | Train Loss 1.692 | Test Loss 1.774 | Train Acc 0.87 | Test Acc 0.64 | Time(s) 0.02
# Epoch 00029 | Train Loss 1.677 | Test Loss 1.765 | Train Acc 0.87 | Test Acc 0.65 | Time(s) 0.02
# Epoch 00030 | Train Loss 1.662 | Test Loss 1.754 | Train Acc 0.87 | Test Acc 0.65 | Time(s) 0.02
# Epoch 00031 | Train Loss 1.646 | Test Loss 1.743 | Train Acc 0.87 | Test Acc 0.67 | Time(s) 0.02
# Epoch 00032 | Train Loss 1.630 | Test Loss 1.732 | Train Acc 0.87 | Test Acc 0.68 | Time(s) 0.02
# Epoch 00033 | Train Loss 1.613 | Test Loss 1.720 | Train Acc 0.88 | Test Acc 0.70 | Time(s) 0.02
# Epoch 00034 | Train Loss 1.596 | Test Loss 1.707 | Train Acc 0.88 | Test Acc 0.72 | Time(s) 0.02
# Epoch 00035 | Train Loss 1.579 | Test Loss 1.695 | Train Acc 0.90 | Test Acc 0.74 | Time(s) 0.02
# Epoch 00036 | Train Loss 1.561 | Test Loss 1.682 | Train Acc 0.91 | Test Acc 0.75 | Time(s) 0.02
# Epoch 00037 | Train Loss 1.544 | Test Loss 1.669 | Train Acc 0.91 | Test Acc 0.76 | Time(s) 0.02
# Epoch 00038 | Train Loss 1.525 | Test Loss 1.656 | Train Acc 0.91 | Test Acc 0.77 | Time(s) 0.02
# Epoch 00039 | Train Loss 1.507 | Test Loss 1.643 | Train Acc 0.91 | Test Acc 0.77 | Time(s) 0.02
# Epoch 00040 | Train Loss 1.489 | Test Loss 1.630 | Train Acc 0.91 | Test Acc 0.79 | Time(s) 0.02
# Epoch 00041 | Train Loss 1.470 | Test Loss 1.617 | Train Acc 0.92 | Test Acc 0.79 | Time(s) 0.02
# Epoch 00042 | Train Loss 1.451 | Test Loss 1.603 | Train Acc 0.94 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00043 | Train Loss 1.432 | Test Loss 1.590 | Train Acc 0.94 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00044 | Train Loss 1.413 | Test Loss 1.576 | Train Acc 0.94 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00045 | Train Loss 1.394 | Test Loss 1.563 | Train Acc 0.94 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00046 | Train Loss 1.375 | Test Loss 1.550 | Train Acc 0.94 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00047 | Train Loss 1.355 | Test Loss 1.537 | Train Acc 0.94 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00048 | Train Loss 1.336 | Test Loss 1.524 | Train Acc 0.94 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00049 | Train Loss 1.316 | Test Loss 1.511 | Train Acc 0.94 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00050 | Train Loss 1.297 | Test Loss 1.498 | Train Acc 0.94 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00051 | Train Loss 1.277 | Test Loss 1.484 | Train Acc 0.95 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00052 | Train Loss 1.258 | Test Loss 1.471 | Train Acc 0.95 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00053 | Train Loss 1.238 | Test Loss 1.457 | Train Acc 0.95 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00054 | Train Loss 1.218 | Test Loss 1.443 | Train Acc 0.96 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00055 | Train Loss 1.199 | Test Loss 1.429 | Train Acc 0.96 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00056 | Train Loss 1.180 | Test Loss 1.414 | Train Acc 0.96 | Test Acc 0.80 | Time(s) 0.02
# Epoch 00057 | Train Loss 1.160 | Test Loss 1.400 | Train Acc 0.95 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00058 | Train Loss 1.141 | Test Loss 1.386 | Train Acc 0.95 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00059 | Train Loss 1.122 | Test Loss 1.372 | Train Acc 0.95 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00060 | Train Loss 1.103 | Test Loss 1.358 | Train Acc 0.95 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00061 | Train Loss 1.084 | Test Loss 1.344 | Train Acc 0.95 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00062 | Train Loss 1.065 | Test Loss 1.331 | Train Acc 0.95 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00063 | Train Loss 1.047 | Test Loss 1.317 | Train Acc 0.95 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00064 | Train Loss 1.028 | Test Loss 1.304 | Train Acc 0.95 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00065 | Train Loss 1.010 | Test Loss 1.290 | Train Acc 0.95 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00066 | Train Loss 0.992 | Test Loss 1.277 | Train Acc 0.95 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00067 | Train Loss 0.974 | Test Loss 1.264 | Train Acc 0.96 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00068 | Train Loss 0.956 | Test Loss 1.251 | Train Acc 0.96 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00069 | Train Loss 0.939 | Test Loss 1.238 | Train Acc 0.96 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00070 | Train Loss 0.921 | Test Loss 1.226 | Train Acc 0.96 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00071 | Train Loss 0.904 | Test Loss 1.213 | Train Acc 0.96 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00072 | Train Loss 0.887 | Test Loss 1.201 | Train Acc 0.96 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00073 | Train Loss 0.871 | Test Loss 1.188 | Train Acc 0.96 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00074 | Train Loss 0.854 | Test Loss 1.176 | Train Acc 0.96 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00075 | Train Loss 0.838 | Test Loss 1.164 | Train Acc 0.96 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00076 | Train Loss 0.822 | Test Loss 1.152 | Train Acc 0.96 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00077 | Train Loss 0.806 | Test Loss 1.141 | Train Acc 0.96 | Test Acc 0.82 | Time(s) 0.02
# Epoch 00078 | Train Loss 0.791 | Test Loss 1.129 | Train Acc 0.96 | Test Acc 0.82 | Time(s) 0.02
# Epoch 00079 | Train Loss 0.776 | Test Loss 1.118 | Train Acc 0.96 | Test Acc 0.82 | Time(s) 0.02
# Epoch 00080 | Train Loss 0.761 | Test Loss 1.108 | Train Acc 0.97 | Test Acc 0.82 | Time(s) 0.02
# Epoch 00081 | Train Loss 0.746 | Test Loss 1.097 | Train Acc 0.97 | Test Acc 0.82 | Time(s) 0.02
# Epoch 00082 | Train Loss 0.732 | Test Loss 1.086 | Train Acc 0.97 | Test Acc 0.82 | Time(s) 0.02
# Epoch 00083 | Train Loss 0.718 | Test Loss 1.076 | Train Acc 0.97 | Test Acc 0.82 | Time(s) 0.02
# Epoch 00084 | Train Loss 0.704 | Test Loss 1.066 | Train Acc 0.97 | Test Acc 0.82 | Time(s) 0.02
# Epoch 00085 | Train Loss 0.690 | Test Loss 1.056 | Train Acc 0.97 | Test Acc 0.82 | Time(s) 0.02
# Epoch 00086 | Train Loss 0.677 | Test Loss 1.046 | Train Acc 0.97 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00087 | Train Loss 0.663 | Test Loss 1.036 | Train Acc 0.97 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00088 | Train Loss 0.650 | Test Loss 1.027 | Train Acc 0.97 | Test Acc 0.82 | Time(s) 0.02
# Epoch 00089 | Train Loss 0.638 | Test Loss 1.018 | Train Acc 0.97 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00090 | Train Loss 0.625 | Test Loss 1.009 | Train Acc 0.97 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00091 | Train Loss 0.613 | Test Loss 1.000 | Train Acc 0.97 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00092 | Train Loss 0.601 | Test Loss 0.992 | Train Acc 0.97 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00093 | Train Loss 0.590 | Test Loss 0.983 | Train Acc 0.97 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00094 | Train Loss 0.578 | Test Loss 0.975 | Train Acc 0.97 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00095 | Train Loss 0.567 | Test Loss 0.967 | Train Acc 0.97 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00096 | Train Loss 0.556 | Test Loss 0.959 | Train Acc 0.97 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00097 | Train Loss 0.545 | Test Loss 0.951 | Train Acc 0.97 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00098 | Train Loss 0.535 | Test Loss 0.944 | Train Acc 0.97 | Test Acc 0.81 | Time(s) 0.02
# Epoch 00099 | Train Loss 0.524 | Test Loss 0.937 | Train Acc 0.97 | Test Acc 0.81 | Time(s) 0.02

# %%
plot(xs, ys, legend=['Train Loss', 'Test Loss', 'Train Accuracy', 'Test Accuracy'], title='GCN Metrics')
